# %%
import pandas as pd



weather = pd.read_csv(‘https://coded2.herokuapp.com/datavizpandas/london2018.csv')
weather

def get_auswertung(ressort):
    genders, aufmacher = get_genders_in(ressort)
    return print("Aufmacher:", aufmacher), pd.Series(genders).value_counts().plot('bar')
# Out:
# acbacbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
# acbcbc
